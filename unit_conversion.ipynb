# %%
import sys,os 
import numpy as np 
from typing import Union, Tuple

# %%
import units_converter as units_converter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import units_converter as units_converter
#
# ModuleNotFoundError: No module named 'units_converter'

# %%
dir( units_converter)
# Out:
# ['Tuple',
#  'Union',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'convert',
#  'convert_dataframe_to_canonical',
#  'convert_to_canonical',
#  'convert_to_english',
#  'convert_to_metric',
#  'convert_to_system',
#  'dimensionless_symbols',
#  'is_known_unit',
#  'np',
#  'pd',
#  'print_conversions',
#  'symbols_for_measurement',
#  'symbols_for_system',
#  'units_table']

# %% [markdown]
# # New version

# %%
#sys.path.append( os.path.join("D:\\","Jupyter"))

#given measurement, get all known symbols: symbols_for_measurement
#given the system (english,canonical,metric) get all known symbols: symbols_for_system
#given a symbol get the measurement: measurement_for_symbol
#units_table: dictionary of all known symbols and their conversion to metric,canonical,english
#dimensionless_symbols: list of symbols of dimensionless quantitites 
#from pysage.units.units_conversion import *

# %%
[ item for item in dir(units_converter) if not item.startswith('_')]
# Out:
# ['Tuple',
#  'Union',
#  'convert',
#  'convert_dataframe_to_canonical',
#  'convert_to_canonical',
#  'convert_to_english',
#  'convert_to_metric',
#  'convert_to_system',
#  'dimensionless_symbols',
#  'is_known_unit',
#  'np',
#  'pd',
#  'print_conversions',
#  'symbols_for_measurement',
#  'symbols_for_system',
#  'units_table']

# %%
units_converter.units_table
# Out:
# {'_': {'symbol': '_',
#   'name': 'dimensionless',
#   'measurement': 'fraction, constant, percent',
#   'metric': {'symbol': '_', 'name': 'dimensionless', 'scale': 1, 'offset': 0},
#   'english': {'symbol': '_', 'name': 'dimensionless', 'scale': 1, 'offset': 0},
#   'canonical': {'symbol': '_',
#    'name': 'dimensionless',
#    'scale': 1,
#    'offset': 0}},
#  'gAPI': {'symbol': 'gAPI',
#   'name': 'API gamma ray',
#   'measurement': 'api_gamma_ray',
#   'metric': {'symbol': 'gAPI',
#    'name': 'API gamma ray',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': 'gAPI',
#    'name': 'API gamma ray',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'gAPI',
#    'name': 'API gamma ray',
#    'scale': 1,
#    'offset': 0}},
#  'nAPI': {'symbol': 'nAPI',
#   'name': 'API neutron',
#   'measurement': 'api_neutron',
#   'metric': {'symbol': 'nAPI', 'name': 'API neutron', 'scale': 1, 'offset': 0},
#   'english': {'symbol': 'nAPI',
#    'name': 'API neutron',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'nAPI',
#    'name': 'API neutron',
#    'scale': 1,
#    'offset': 0}},
#  'dAPI': {'symbol': 'dAPI',
#   'name': 'API gravity',
#   'measurement': 'api_oil_gravity',
#   'metric': {'symbol': 'dAPI', 'name': 'API gravity', 'scale': 1, 'offset': 0},
#   'english': {'symbol': 'dAPI',
#    'name': 'API gravity',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'dAPI',
#    'name': 'API gravity',
#    'scale': 1,
#    'offset': 0}},
#  'ft/s2': {'symbol': 'ft/s2',
#   'name': 'foot per square second',
#   'measurement': 'acceleration',
#   'metric': {'symbol': 'm/s2',
#    'name': 'meter per square second',
#    'scale': 0.30479999999999996,
#    'offset': 0},
#   'english': {'symbol': 'ft/s2',
#    'name': 'foot per square second',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'm/s2',
#    'name': 'meter per square second',
#    'scale': 0.30479999999999996,
#    'offset': 0}},
#  'Gal': {'symbol': 'Gal',
#   'name': 'galileo',
#   'measurement': 'acceleration',
#   'metric': {'symbol': 'm/s2',
#    'name': 'meter per square second',
#    'scale': 0.010000000000000002,
#    'offset': 0},
#   'english': {'symbol': 'ft/s2',
#    'name': 'foot per square second',
#    'scale': 0.03280839895013124,
#    'offset': 0},
#   'canonical': {'symbol': 'm/s2',
#    'name': 'meter per square second',
#    'scale': 0.010000000000000002,
#    'offset': 0}},
#  'gn': {'symbol': 'gn',
#   'name': 'gravity',
#   'measurement': 'acceleration',
#   'metric': {'symbol': 'm/s2',
#    'name': 'meter per square second',
#    'scale': 9.806649999999998,
#    'offset': 0},
#   'english': {'symbol': 'ft/s2',
#    'name': 'foot per square second',
#    'scale': 32.17404855643045,
#    'offset': 0},
#   'canonical': {'symbol': 'm/s2',
#    'name': 'meter per square second',
#    'scale': 9.806649999999998,
#    'offset': 0}},
#  'm/s2': {'symbol': 'm/s2',
#   'name': 'meter per square second',
#   'measurement': 'acceleration',
#   'metric': {'symbol': 'm/s2',
#    'name': 'meter per square second',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': 'ft/s2',
#    'name': 'foot per square second',
#    'scale': 3.2808398950131226,
#    'offset': 0},
#   'canonical': {'symbol': 'm/s2',
#    'name': 'meter per square second',
#    'scale': 1,
#    'offset': 0}},
#  'mGal': {'symbol': 'mGal',
#   'name': 'milligal',
#   'measurement': 'acceleration',
#   'metric': {'symbol': 'm/s2',
#    'name': 'meter per square second',
#    'scale': 1e-05,
#    'offset': 0},
#   'english': {'symbol': 'ft/s2',
#    'name': 'foot per square second',
#    'scale': 3.280839895013123e-05,
#    'offset': 0},
#   'canonical': {'symbol': 'm/s2',
#    'name': 'meter per square second',
#    'scale': 1e-05,
#    'offset': 0}},
#  'mgn': {'symbol': 'mgn',
#   'name': 'milligravity',
#   'measurement': 'acceleration',
#   'metric': {'symbol': 'm/s2',
#    'name': 'meter per square second',
#    'scale': 0.00980665,
#    'offset': 0},
#   'english': {'symbol': 'ft/s2',
#    'name': 'foot per square second',
#    'scale': 0.03217404855643044,
#    'offset': 0},
#   'canonical': {'symbol': 'm/s2',
#    'name': 'meter per square second',
#    'scale': 0.00980665,
#    'offset': 0}},
#  'uGal': {'symbol': 'uGal',
#   'name': 'micro Galileo',
#   'measurement': 'acceleration',
#   'metric': {'symbol': 'm/s2',
#    'name': 'meter per square second',
#    'scale': 1e-08,
#    'offset': 0},
#   'english': {'symbol': 'ft/s2',
#    'name': 'foot per square second',
#    'scale': 3.280839895013123e-08,
#    'offset': 0},
#   'canonical': {'symbol': 'm/s2',
#    'name': 'meter per square second',
#    'scale': 1e-08,
#    'offset': 0}},
#  'gm-mole': {'symbol': 'gm-mole',
#   'name': 'gram mole',
#   'measurement': 'amount_of_substance',
#   'metric': {'symbol': 'mol', 'name': 'mole', 'scale': 1, 'offset': 0},
#   'english': {'symbol': 'mol', 'name': 'mole', 'scale': 1, 'offset': 0},
#   'canonical': {'symbol': 'mol', 'name': 'mole', 'scale': 1, 'offset': 0}},
#  'kg-mole': {'symbol': 'kg-mole',
#   'name': 'kg mole',
#   'measurement': 'amount_of_substance',
#   'metric': {'symbol': 'mol', 'name': 'mole', 'scale': 1000, 'offset': 0},
#   'english': {'symbol': 'mol', 'name': 'mole', 'scale': 1000, 'offset': 0},
#   'canonical': {'symbol': 'mol', 'name': 'mole', 'scale': 1000, 'offset': 0}},
#  'kmol': {'symbol': 'kmol',
#   'name': 'kilomole',
#   'measurement': 'amount_of_substance',
#   'metric': {'symbol': 'mol', 'name': 'mole', 'scale': 1000, 'offset': 0},
#   'english': {'symbol': 'mol', 'name': 'mole', 'scale': 1000, 'offset': 0},
#   'canonical': {'symbol': 'mol', 'name': 'mole', 'scale': 1000, 'offset': 0}},
#  'lb-mole': {'symbol': 'lb-mole',
#   'name': 'pound mole',
#   'measurement': 'amount_of_substance',
#   'metric': {'symbol': 'mol',
#    'name': 'mole',
#    'scale': 453.5923700000001,
#    'offset': 0},
#   'english': {'symbol': 'mol',
#    'name': 'mole',
#    'scale': 453.5923700000001,
#    'offset': 0},
#   'canonical': {'symbol': 'mol',
#    'name': 'mole',
#    'scale': 453.5923700000001,
#    'offset': 0}},
#  'mmol': {'symbol': 'mmol',
#   'name': 'millimole',
#   'measurement': 'amount_of_substance',
#   'metric': {'symbol': 'mol', 'name': 'mole', 'scale': 0.001, 'offset': 0},
#   'english': {'symbol': 'mol', 'name': 'mole', 'scale': 0.001, 'offset': 0},
#   'canonical': {'symbol': 'mol', 'name': 'mole', 'scale': 0.001, 'offset': 0}},
#  'mol': {'symbol': 'mol',
#   'name': 'mole',
#   'measurement': 'amount_of_substance',
#   'metric': {'symbol': 'mol', 'name': 'mole', 'scale': 1, 'offset': 0},
#   'english': {'symbol': 'mol', 'name': 'mole', 'scale': 1, 'offset': 0},
#   'canonical': {'symbol': 'mol', 'name': 'mole', 'scale': 1, 'offset': 0}},
#  'umol': {'symbol': 'umol',
#   'name': 'micromole',
#   'measurement': 'amount_of_substance',
#   'metric': {'symbol': 'mol',
#    'name': 'mole',
#    'scale': 9.999999999999997e-07,
#    'offset': 0},
#   'english': {'symbol': 'mol',
#    'name': 'mole',
#    'scale': 9.999999999999997e-07,
#    'offset': 0},
#   'canonical': {'symbol': 'mol',
#    'name': 'mole',
#    'scale': 9.999999999999997e-07,
#    'offset': 0}},
#  'c/gal': {'symbol': 'c/gal',
#   'name': 'revolution per gallon',
#   'measurement': 'angle_per_volume',
#   'metric': {'symbol': 'c/m3',
#    'name': 'revolution per cubic meter',
#    'scale': 264.172037284185,
#    'offset': 0},
#   'english': {'symbol': 'c/gal',
#    'name': 'revolution per gallon',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'rad/m3',
#    'name': 'radian per cubic meter',
#    'scale': 1659.8418632316902,
#    'offset': 0}},
#  'c/m3': {'symbol': 'c/m3',
#   'name': 'revolution per cubic meter',
#   'measurement': 'angle_per_volume',
#   'metric': {'symbol': 'c/m3',
#    'name': 'revolution per cubic meter',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': 'c/gal',
#    'name': 'revolution per gallon',
#    'scale': 0.003785411999999995,
#    'offset': 0},
#   'canonical': {'symbol': 'rad/m3',
#    'name': 'radian per cubic meter',
#    'scale': 6.28318530717959,
#    'offset': 0}},
#  'rad/ft3': {'symbol': 'rad/ft3',
#   'name': 'radian per cubic foot',
#   'measurement': 'angle_per_volume',
#   'metric': {'symbol': 'c/m3',
#    'name': 'revolution per cubic meter',
#    'scale': 5.6205037723677655,
#    'offset': 0},
#   'english': {'symbol': 'c/gal',
#    'name': 'revolution per gallon',
#    'scale': 0.021275922425966175,
#    'offset': 0},
#   'canonical': {'symbol': 'rad/m3',
#    'name': 'radian per cubic meter',
#    'scale': 35.31466672148859,
#    'offset': 0}},
#  'rad/m3': {'symbol': 'rad/m3',
#   'name': 'radian per cubic meter',
#   'measurement': 'angle_per_volume',
#   'metric': {'symbol': 'c/m3',
#    'name': 'revolution per cubic meter',
#    'scale': 0.15915494309189526,
#    'offset': 0},
#   'english': {'symbol': 'c/gal',
#    'name': 'revolution per gallon',
#    'scale': 0.0006024670314393765,
#    'offset': 0},
#   'canonical': {'symbol': 'rad/m3',
#    'name': 'radian per cubic meter',
#    'scale': 1,
#    'offset': 0}},
#  'acre': {'symbol': 'acre',
#   'name': 'acre',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 4046.8726098742513,
#    'offset': 0},
#   'english': {'symbol': 'ft2',
#    'name': 'square foot',
#    'scale': 43560.17424052272,
#    'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 4046.8726098742513,
#    'offset': 0}},
#  'b': {'symbol': 'b',
#   'name': 'barn',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 1e-28,
#    'offset': 0},
#   'english': {'symbol': 'ft2',
#    'name': 'square foot',
#    'scale': 1.0763910416709721e-27,
#    'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 1e-28,
#    'offset': 0}},
#  'bbl/ft': {'symbol': 'bbl/ft',
#   'name': 'Barrel per foot',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 0.521611889763779,
#    'offset': 0},
#   'english': {'symbol': 'ft2',
#    'name': 'square foot',
#    'scale': 5.614583653707985,
#    'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 0.521611889763779,
#    'offset': 0}},
#  'cm2': {'symbol': 'cm2',
#   'name': 'square centimeter',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 9.999999999999999e-05,
#    'offset': 0},
#   'english': {'symbol': 'ft2',
#    'name': 'square foot',
#    'scale': 0.0010763910416709726,
#    'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 9.999999999999999e-05,
#    'offset': 0}},
#  'D': {'symbol': 'D',
#   'name': 'darcy',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 9.869232999999999e-13,
#    'offset': 0},
#   'english': {'symbol': 'ft2',
#    'name': 'square foot',
#    'scale': 1.0623153989363533e-11,
#    'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 9.869232999999999e-13,
#    'offset': 0}},
#  'ft2': {'symbol': 'ft2',
#   'name': 'square foot',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 0.09290303999999999,
#    'offset': 0},
#   'english': {'symbol': 'ft2', 'name': 'square foot', 'scale': 1, 'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 0.09290303999999999,
#    'offset': 0}},
#  'gal/ft': {'symbol': 'gal/ft',
#   'name': 'gallon per foot',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 0.01241933070866142,
#    'offset': 0},
#   'english': {'symbol': 'ft2',
#    'name': 'square foot',
#    'scale': 0.1336805631835236,
#    'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 0.01241933070866142,
#    'offset': 0}},
#  'ha': {'symbol': 'ha',
#   'name': 'hectare',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 10000,
#    'offset': 0},
#   'english': {'symbol': 'ft2',
#    'name': 'square foot',
#    'scale': 107639.10416709722,
#    'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 10000,
#    'offset': 0}},
#  'in2': {'symbol': 'in2',
#   'name': 'square inch',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 0.0006451600000000001,
#    'offset': 0},
#   'english': {'symbol': 'ft2',
#    'name': 'square foot',
#    'scale': 0.006944444444444444,
#    'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 0.0006451600000000001,
#    'offset': 0}},
#  'km2': {'symbol': 'km2',
#   'name': 'square kilometer',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 1000000,
#    'offset': 0},
#   'english': {'symbol': 'ft2',
#    'name': 'square foot',
#    'scale': 10763910.416709721,
#    'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 1000000,
#    'offset': 0}},
#  'm2': {'symbol': 'm2',
#   'name': 'square meter',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2', 'name': 'square meter', 'scale': 1, 'offset': 0},
#   'english': {'symbol': 'ft2',
#    'name': 'square foot',
#    'scale': 10.763910416709722,
#    'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 1,
#    'offset': 0}},
#  'm3/m': {'symbol': 'm3/m',
#   'name': 'cubic meter per meter',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2', 'name': 'square meter', 'scale': 1, 'offset': 0},
#   'english': {'symbol': 'ft2',
#    'name': 'square foot',
#    'scale': 10.763910416709722,
#    'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 1,
#    'offset': 0}},
#  'mD': {'symbol': 'mD',
#   'name': 'millidarcy',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 9.869233e-16,
#    'offset': 0},
#   'english': {'symbol': 'ft2',
#    'name': 'square foot',
#    'scale': 1.0623153989363533e-14,
#    'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 9.869233e-16,
#    'offset': 0}},
#  'mi2': {'symbol': 'mi2',
#   'name': 'square mile',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 2589988.110336,
#    'offset': 0},
#   'english': {'symbol': 'ft2',
#    'name': 'square foot',
#    'scale': 27878400,
#    'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 2589988.110336,
#    'offset': 0}},
#  'mm2': {'symbol': 'mm2',
#   'name': 'square millimeter',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 9.999999999999997e-07,
#    'offset': 0},
#   'english': {'symbol': 'ft2',
#    'name': 'square foot',
#    'scale': 1.0763910416709721e-05,
#    'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 9.999999999999997e-07,
#    'offset': 0}},
#  'MSCF/ft': {'symbol': 'MSCF/ft',
#   'name': 'Thousand standard cubic feet per foot',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 92.90304,
#    'offset': 0},
#   'english': {'symbol': 'ft2',
#    'name': 'square foot',
#    'scale': 1000,
#    'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 92.90304,
#    'offset': 0}},
#  'nD': {'symbol': 'nD',
#   'name': 'nanodarcy',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 9.869232999999998e-22,
#    'offset': 0},
#   'english': {'symbol': 'ft2',
#    'name': 'square foot',
#    'scale': 1.0623153989363534e-20,
#    'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 9.869232999999998e-22,
#    'offset': 0}},
#  'sm3/m': {'symbol': 'sm3/m',
#   'name': 'Standard cubic meters per meter',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2', 'name': 'square meter', 'scale': 1, 'offset': 0},
#   'english': {'symbol': 'ft2',
#    'name': 'square foot',
#    'scale': 10.763910416709722,
#    'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 1,
#    'offset': 0}},
#  'STB/ft': {'symbol': 'STB/ft',
#   'name': 'Stock tank barrels per foot',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 0.52161187664042,
#    'offset': 0},
#   'english': {'symbol': 'ft2',
#    'name': 'square foot',
#    'scale': 5.614583512449323,
#    'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 0.52161187664042,
#    'offset': 0}},
#  'uD': {'symbol': 'uD',
#   'name': 'microdarcy',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 9.869233e-19,
#    'offset': 0},
#   'english': {'symbol': 'ft2',
#    'name': 'square foot',
#    'scale': 1.0623153989363534e-17,
#    'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 9.869233e-19,
#    'offset': 0}},
#  'um2': {'symbol': 'um2',
#   'name': 'square micrometer',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 1e-12,
#    'offset': 0},
#   'english': {'symbol': 'ft2',
#    'name': 'square foot',
#    'scale': 1.076391041670972e-11,
#    'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 1e-12,
#    'offset': 0}},
#  'yd2': {'symbol': 'yd2',
#   'name': 'square yard',
#   'measurement': 'area',
#   'metric': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 0.8361273600000001,
#    'offset': 0},
#   'english': {'symbol': 'ft2', 'name': 'square foot', 'scale': 9, 'offset': 0},
#   'canonical': {'symbol': 'm2',
#    'name': 'square meter',
#    'scale': 0.8361273600000001,
#    'offset': 0}},
#  'm2/g': {'symbol': 'm2/g',
#   'name': 'square meter per gram',
#   'measurement': 'area_per_mass',
#   'metric': {'symbol': 'm2/g',
#    'name': 'square meter per gram',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': 'm2/g',
#    'name': 'square meter per gram',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/kg',
#    'name': 'square meter per kilogram',
#    'scale': 1000,
#    'offset': 0}},
#  'm2/kg': {'symbol': 'm2/kg',
#   'name': 'square meter per kilogram',
#   'measurement': 'area_per_mass',
#   'metric': {'symbol': 'm2/g',
#    'name': 'square meter per gram',
#    'scale': 0.001,
#    'offset': 0},
#   'english': {'symbol': 'm2/g',
#    'name': 'square meter per gram',
#    'scale': 0.001,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/kg',
#    'name': 'square meter per kilogram',
#    'scale': 1,
#    'offset': 0}},
#  'bbl/(d.ft)': {'symbol': 'bbl/(d.ft)',
#   'name': 'barrel per day per foot',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 6.037174650043744e-06,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 6.037174650043744e-06,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 6.037174650043744e-06,
#    'offset': 0}},
#  'cm2/h': {'symbol': 'cm2/h',
#   'name': 'square centimeter per hour',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 2.77777777777778e-08,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 2.77777777777778e-08,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 2.77777777777778e-08,
#    'offset': 0}},
#  'cm2/s': {'symbol': 'cm2/s',
#   'name': 'square centimeter per second',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 9.999999999999999e-05,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 9.999999999999999e-05,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 9.999999999999999e-05,
#    'offset': 0}},
#  'ft2/d': {'symbol': 'ft2/d',
#   'name': 'square foot per day',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1.07526666666667e-06,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1.07526666666667e-06,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1.07526666666667e-06,
#    'offset': 0}},
#  'ft2/h': {'symbol': 'ft2/h',
#   'name': 'square foot per hour',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 2.5806400000000004e-05,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 2.5806400000000004e-05,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 2.5806400000000004e-05,
#    'offset': 0}},
#  'ft2/s': {'symbol': 'ft2/s',
#   'name': 'square foot per second',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 0.09290303999999999,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 0.09290303999999999,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 0.09290303999999999,
#    'offset': 0}},
#  'in2/s': {'symbol': 'in2/s',
#   'name': 'square inch per second',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 0.0006451600000000001,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 0.0006451600000000001,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 0.0006451600000000001,
#    'offset': 0}},
#  'km2/Ma': {'symbol': 'km2/Ma',
#   'name': 'square kilometer per million years',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 3.16875355494539e-08,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 3.16875355494539e-08,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 3.16875355494539e-08,
#    'offset': 0}},
#  'm2/d': {'symbol': 'm2/d',
#   'name': 'square meter per day',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1.15740740740741e-05,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1.15740740740741e-05,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1.15740740740741e-05,
#    'offset': 0}},
#  'm2/h': {'symbol': 'm2/h',
#   'name': 'square meter per hour',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 0.0002777777777777778,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 0.0002777777777777778,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 0.0002777777777777778,
#    'offset': 0}},
#  'm2/s': {'symbol': 'm2/s',
#   'name': 'square meter per second',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1,
#    'offset': 0}},
#  'm3/(d.m)': {'symbol': 'm3/(d.m)',
#   'name': 'cubic meter per day per meter',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1.157407407407407e-05,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1.157407407407407e-05,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1.157407407407407e-05,
#    'offset': 0}},
#  'm3/(h.m)': {'symbol': 'm3/(h.m)',
#   'name': 'cubic meter per hour per meter',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 0.0002777777777777778,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 0.0002777777777777778,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 0.0002777777777777778,
#    'offset': 0}},
#  'm3/(m.s)': {'symbol': 'm3/(m.s)',
#   'name': 'cubic meter per second per meter',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1,
#    'offset': 0}},
#  'm3/(s.ft)': {'symbol': 'm3/(s.ft)',
#   'name': 'cubic meter per second per foot',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 3.2808398950131226,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 3.2808398950131226,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 3.2808398950131226,
#    'offset': 0}},
#  'm3/(s.m)': {'symbol': 'm3/(s.m)',
#   'name': 'cubic meter per second per meter',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1,
#    'offset': 0}},
#  'mm2/s': {'symbol': 'mm2/s',
#   'name': 'square millimeter per second',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 9.999999999999997e-07,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 9.999999999999997e-07,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 9.999999999999997e-07,
#    'offset': 0}},
#  'MSCF/(d.ft)': {'symbol': 'MSCF/(d.ft)',
#   'name': 'Thousand standard cubic feet per day per foot',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 0.00107526666666667,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 0.00107526666666667,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 0.00107526666666667,
#    'offset': 0}},
#  'sm3/(d.m)': {'symbol': 'sm3/(d.m)',
#   'name': 'Standard cubic meters per day per meter',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1.15740740740741e-05,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1.15740740740741e-05,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1.15740740740741e-05,
#    'offset': 0}},
#  'STB/(d.ft)': {'symbol': 'STB/(d.ft)',
#   'name': 'Stock tank barrels per day per foot',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 6.03717449815301e-06,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 6.03717449815301e-06,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 6.03717449815301e-06,
#    'offset': 0}},
#  'um2/s': {'symbol': 'um2/s',
#   'name': 'square micrometer per second',
#   'measurement': 'area_per_time',
#   'metric': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1e-12,
#    'offset': 0},
#   'english': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1e-12,
#    'offset': 0},
#   'canonical': {'symbol': 'm2/s',
#    'name': 'square meter per second',
#    'scale': 1e-12,
#    'offset': 0}},
#  'cm4': {'symbol': 'cm4',
#   'name': 'centimeter to the fourth',
#   'measurement': 'area_squared',
#   'metric': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 1e-08,
#    'offset': 0},
#   'english': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 1e-08,
#    'offset': 0},
#   'canonical': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 1e-08,
#    'offset': 0}},
#  'ft4': {'symbol': 'ft4',
#   'name': 'foot to the fourth',
#   'measurement': 'area_squared',
#   'metric': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 0.0086309748412416,
#    'offset': 0},
#   'english': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 0.0086309748412416,
#    'offset': 0},
#   'canonical': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 0.0086309748412416,
#    'offset': 0}},
#  'in4': {'symbol': 'in4',
#   'name': 'inch to the fourth',
#   'measurement': 'area_squared',
#   'metric': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 4.162314256e-07,
#    'offset': 0},
#   'english': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 4.162314256e-07,
#    'offset': 0},
#   'canonical': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 4.162314256e-07,
#    'offset': 0}},
#  'm4': {'symbol': 'm4',
#   'name': 'meter to the fourth',
#   'measurement': 'area_squared',
#   'metric': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 1,
#    'offset': 0}},
#  'mD.cm2': {'symbol': 'mD.cm2',
#   'name': 'millidarcy centimeter squared',
#   'measurement': 'area_squared',
#   'metric': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 9.86923266716012e-20,
#    'offset': 0},
#   'english': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 9.86923266716012e-20,
#    'offset': 0},
#   'canonical': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 9.86923266716012e-20,
#    'offset': 0}},
#  'mD.ft2': {'symbol': 'mD.ft2',
#   'name': 'millidarcy foot squared',
#   'measurement': 'area_squared',
#   'metric': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 9.168817172464841e-17,
#    'offset': 0},
#   'english': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 9.168817172464841e-17,
#    'offset': 0},
#   'canonical': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 9.168817172464841e-17,
#    'offset': 0}},
#  'mD.m2': {'symbol': 'mD.m2',
#   'name': 'millidarcy meter squared',
#   'measurement': 'area_squared',
#   'metric': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 9.86923266716012e-16,
#    'offset': 0},
#   'english': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 9.86923266716012e-16,
#    'offset': 0},
#   'canonical': {'symbol': 'm4',
#    'name': 'meter to the fourth',
#    'scale': 9.86923266716012e-16,
#    'offset': 0}},
#  'B': {'symbol': 'B',
#   'name': 'bel',
#   'measurement': 'attenuation',
#   'metric': {'symbol': 'dB', 'name': 'decibel', 'scale': 10, 'offset': 0},
#   'english': {'symbol': 'dB', 'name': 'decibel', 'scale': 10, 'offset': 0},
#   'canonical': {'symbol': 'dB', 'name': 'decibel', 'scale': 10, 'offset': 0}},
#  'dB': {'symbol': 'dB',
#   'name': 'decibel',
#   'measurement': 'attenuation',
#   'metric': {'symbol': 'dB', 'name': 'decibel', 'scale': 1, 'offset': 0},
#   'english': {'symbol': 'dB', 'name': 'decibel', 'scale': 1, 'offset': 0},
#   'canonical': {'symbol': 'dB', 'name': 'decibel', 'scale': 1, 'offset': 0}},
#  'dB/ft': {'symbol': 'dB/ft',
#   'name': 'decibel per foot',
#   'measurement': 'attenuation_per_length',
#   'metric': {'symbol': 'dB/m',
#    'name': 'decibel per meter',
#    'scale': 3.2808398950131226,
#    'offset': 0},
#   'english': {'symbol': 'dB/ft',
#    'name': 'decibel per foot',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'dB/m',
#    'name': 'decibel per meter',
#    'scale': 3.2808398950131226,
#    'offset': 0}},
#  'dB/m': {'symbol': 'dB/m',
#   'name': 'decibel per meter',
#   'measurement': 'attenuation_per_length',
#   'metric': {'symbol': 'dB/m',
#    'name': 'decibel per meter',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': 'dB/ft',
#    'name': 'decibel per foot',
#    'scale': 0.30479999999999996,
#    'offset': 0},
#   'canonical': {'symbol': 'dB/m',
#    'name': 'decibel per meter',
#    'scale': 1,
#    'offset': 0}},
#  'F': {'symbol': 'F',
#   'name': 'farad',
#   'measurement': 'capacitance',
#   'metric': {'symbol': 'uF',
#    'name': 'microfarad',
#    'scale': 1000000,
#    'offset': 0},
#   'english': {'symbol': 'uF',
#    'name': 'microfarad',
#    'scale': 1000000,
#    'offset': 0},
#   'canonical': {'symbol': 'F', 'name': 'farad', 'scale': 1, 'offset': 0}},
#  'pF': {'symbol': 'pF',
#   'name': 'picofarad',
#   'measurement': 'capacitance',
#   'metric': {'symbol': 'uF',
#    'name': 'microfarad',
#    'scale': 9.999999999999997e-07,
#    'offset': 0},
#   'english': {'symbol': 'uF',
#    'name': 'microfarad',
#    'scale': 9.999999999999997e-07,
#    'offset': 0},
#   'canonical': {'symbol': 'F', 'name': 'farad', 'scale': 1e-12, 'offset': 0}},
#  'uF': {'symbol': 'uF',
#   'name': 'microfarad',
#   'measurement': 'capacitance',
#   'metric': {'symbol': 'uF', 'name': 'microfarad', 'scale': 1, 'offset': 0},
#   'english': {'symbol': 'uF', 'name': 'microfarad', 'scale': 1, 'offset': 0},
#   'canonical': {'symbol': 'F',
#    'name': 'farad',
#    'scale': 9.999999999999997e-07,
#    'offset': 0}},
#  'F/m': {'symbol': 'F/m',
#   'name': 'farad per meter',
#   'measurement': 'capacitance_per_length',
#   'metric': {'symbol': 'uF/m',
#    'name': 'microfarad per meter',
#    'scale': 1000000,
#    'offset': 0},
#   'english': {'symbol': 'uF/m',
#    'name': 'microfarad per meter',
#    'scale': 1000000,
#    'offset': 0},
#   'canonical': {'symbol': 'F/m',
#    'name': 'farad per meter',
#    'scale': 1,
#    'offset': 0}},
#  'uF/m': {'symbol': 'uF/m',
#   'name': 'microfarad per meter',
#   'measurement': 'capacitance_per_length',
#   'metric': {'symbol': 'uF/m',
#    'name': 'microfarad per meter',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': 'uF/m',
#    'name': 'microfarad per meter',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'F/m',
#    'name': 'farad per meter',
#    'scale': 9.999999999999997e-07,
#    'offset': 0}},
#  'GS': {'symbol': 'GS',
#   'name': 'gigasiemens',
#   'measurement': 'conductance',
#   'metric': {'symbol': 'S',
#    'name': 'siemens',
#    'scale': 1000000000,
#    'offset': 0},
#   'english': {'symbol': 'S',
#    'name': 'siemens',
#    'scale': 1000000000,
#    'offset': 0},
#   'canonical': {'symbol': 'S',
#    'name': 'siemens',
#    'scale': 1000000000,
#    'offset': 0}},
#  'kS': {'symbol': 'kS',
#   'name': 'kilosiemens',
#   'measurement': 'conductance',
#   'metric': {'symbol': 'S', 'name': 'siemens', 'scale': 1000, 'offset': 0},
#   'english': {'symbol': 'S', 'name': 'siemens', 'scale': 1000, 'offset': 0},
#   'canonical': {'symbol': 'S', 'name': 'siemens', 'scale': 1000, 'offset': 0}},
#  'mS': {'symbol': 'mS',
#   'name': 'millisiemens',
#   'measurement': 'conductance',
#   'metric': {'symbol': 'S', 'name': 'siemens', 'scale': 0.001, 'offset': 0},
#   'english': {'symbol': 'S', 'name': 'siemens', 'scale': 0.001, 'offset': 0},
#   'canonical': {'symbol': 'S',
#    'name': 'siemens',
#    'scale': 0.001,
#    'offset': 0}},
#  'pS': {'symbol': 'pS',
#   'name': 'picosiemens',
#   'measurement': 'conductance',
#   'metric': {'symbol': 'S', 'name': 'siemens', 'scale': 1e-12, 'offset': 0},
#   'english': {'symbol': 'S', 'name': 'siemens', 'scale': 1e-12, 'offset': 0},
#   'canonical': {'symbol': 'S',
#    'name': 'siemens',
#    'scale': 1e-12,
#    'offset': 0}},
#  'S': {'symbol': 'S',
#   'name': 'siemens',
#   'measurement': 'conductance',
#   'metric': {'symbol': 'S', 'name': 'siemens', 'scale': 1, 'offset': 0},
#   'english': {'symbol': 'S', 'name': 'siemens', 'scale': 1, 'offset': 0},
#   'canonical': {'symbol': 'S', 'name': 'siemens', 'scale': 1, 'offset': 0}},
#  'uS': {'symbol': 'uS',
#   'name': 'microsiemens',
#   'measurement': 'conductance',
#   'metric': {'symbol': 'S',
#    'name': 'siemens',
#    'scale': 9.999999999999997e-07,
#    'offset': 0},
#   'english': {'symbol': 'S',
#    'name': 'siemens',
#    'scale': 9.999999999999997e-07,
#    'offset': 0},
#   'canonical': {'symbol': 'S',
#    'name': 'siemens',
#    'scale': 9.999999999999997e-07,
#    'offset': 0}},
#  'kS/m': {'symbol': 'kS/m',
#   'name': 'kilosiemens per meter',
#   'measurement': 'conductivity',
#   'metric': {'symbol': 'mS/m',
#    'name': 'millisiemens per meter',
#    'scale': 1000000,
#    'offset': 0},
#   'english': {'symbol': 'mS/m',
#    'name': 'millisiemens per meter',
#    'scale': 1000000,
#    'offset': 0},
#   'canonical': {'symbol': 'S/m',
#    'name': 'siemens per meter',
#    'scale': 1000,
#    'offset': 0}},
#  'mS/cm': {'symbol': 'mS/cm',
#   'name': 'millisiemens per centimeter',
#   'measurement': 'conductivity',
#   'metric': {'symbol': 'mS/m',
#    'name': 'millisiemens per meter',
#    'scale': 100,
#    'offset': 0},
#   'english': {'symbol': 'mS/m',
#    'name': 'millisiemens per meter',
#    'scale': 100,
#    'offset': 0},
#   'canonical': {'symbol': 'S/m',
#    'name': 'siemens per meter',
#    'scale': 0.1,
#    'offset': 0}},
#  'mS/m': {'symbol': 'mS/m',
#   'name': 'millisiemens per meter',
#   'measurement': 'conductivity',
#   'metric': {'symbol': 'mS/m',
#    'name': 'millisiemens per meter',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': 'mS/m',
#    'name': 'millisiemens per meter',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'S/m',
#    'name': 'siemens per meter',
#    'scale': 0.001,
#    'offset': 0}},
#  'S/m': {'symbol': 'S/m',
#   'name': 'siemens per meter',
#   'measurement': 'conductivity',
#   'metric': {'symbol': 'mS/m',
#    'name': 'millisiemens per meter',
#    'scale': 1000,
#    'offset': 0},
#   'english': {'symbol': 'mS/m',
#    'name': 'millisiemens per meter',
#    'scale': 1000,
#    'offset': 0},
#   'canonical': {'symbol': 'S/m',
#    'name': 'siemens per meter',
#    'scale': 1,
#    'offset': 0}},
#  'uS/cm': {'symbol': 'uS/cm',
#   'name': 'microsiemens per centimeter',
#   'measurement': 'conductivity',
#   'metric': {'symbol': 'mS/m',
#    'name': 'millisiemens per meter',
#    'scale': 0.1,
#    'offset': 0},
#   'english': {'symbol': 'mS/m',
#    'name': 'millisiemens per meter',
#    'scale': 0.1,
#    'offset': 0},
#   'canonical': {'symbol': 'S/m',
#    'name': 'siemens per meter',
#    'scale': 9.999999999999999e-05,
#    'offset': 0}},
#  '(S/m)/(meq/cm3)': {'symbol': '(S/m)/(meq/cm3)',
#   'name': '(siemen per meter) per (millieqivalent per cubic centimeter)',
#   'measurement': 'counterion_conductivity',
#   'metric': {'symbol': '(S/m)/(meq/cm3)',
#    'name': '(siemen per meter) per (millieqivalent per cubic centimeter)',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': '(S/m)/(meq/cm3)',
#    'name': '(siemen per meter) per (millieqivalent per cubic centimeter)',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'A.s2/kg',
#    'name': 'ampere second squared per kilogram',
#    'scale': 1.036409049923824e-08,
#    'offset': 0}},
#  'A.s2/kg': {'symbol': 'A.s2/kg',
#   'name': 'ampere second squared per kilogram',
#   'measurement': 'counterion_conductivity',
#   'metric': {'symbol': '(S/m)/(meq/cm3)',
#    'name': '(siemen per meter) per (millieqivalent per cubic centimeter)',
#    'scale': 96487000,
#    'offset': 0},
#   'english': {'symbol': '(S/m)/(meq/cm3)',
#    'name': '(siemen per meter) per (millieqivalent per cubic centimeter)',
#    'scale': 96487000,
#    'offset': 0},
#   'canonical': {'symbol': 'A.s2/kg',
#    'name': 'ampere second squared per kilogram',
#    'scale': 1,
#    'offset': 0}},
#  'mS.m2/eq': {'symbol': 'mS.m2/eq',
#   'name': '(siemen per meter) per (millieqivalent per cubic centimeter)',
#   'measurement': 'counterion_conductivity',
#   'metric': {'symbol': '(S/m)/(meq/cm3)',
#    'name': '(siemen per meter) per (millieqivalent per cubic centimeter)',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': '(S/m)/(meq/cm3)',
#    'name': '(siemen per meter) per (millieqivalent per cubic centimeter)',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'A.s2/kg',
#    'name': 'ampere second squared per kilogram',
#    'scale': 1.036409049923824e-08,
#    'offset': 0}},
#  'Sm2/Mol': {'symbol': 'Sm2/Mol',
#   'name': '(siemens per m) per (mol per m3) for monovalent ions',
#   'measurement': 'counterion_conductivity',
#   'metric': {'symbol': '(S/m)/(meq/cm3)',
#    'name': '(siemen per meter) per (millieqivalent per cubic centimeter)',
#    'scale': 96487000,
#    'offset': 0},
#   'english': {'symbol': '(S/m)/(meq/cm3)',
#    'name': '(siemen per meter) per (millieqivalent per cubic centimeter)',
#    'scale': 96487000,
#    'offset': 0},
#   'canonical': {'symbol': 'A.s2/kg',
#    'name': 'ampere second squared per kilogram',
#    'scale': 1,
#    'offset': 0}},
#  'A/cm2': {'symbol': 'A/cm2',
#   'name': 'ampere per square centimeter',
#   'measurement': 'current_density',
#   'metric': {'symbol': 'uA/cm2',
#    'name': 'microampere per square centimeter',
#    'scale': 1000000,
#    'offset': 0},
#   'english': {'symbol': 'uA/cm2',
#    'name': 'microampere per square centimeter',
#    'scale': 1000000,
#    'offset': 0},
#   'canonical': {'symbol': 'A/m2',
#    'name': 'ampere per square meter',
#    'scale': 10000,
#    'offset': 0}},
#  'A/ft2': {'symbol': 'A/ft2',
#   'name': 'ampere per square foot',
#   'measurement': 'current_density',
#   'metric': {'symbol': 'uA/cm2',
#    'name': 'microampere per square centimeter',
#    'scale': 1076.3910416709723,
#    'offset': 0},
#   'english': {'symbol': 'uA/cm2',
#    'name': 'microampere per square centimeter',
#    'scale': 1076.3910416709723,
#    'offset': 0},
#   'canonical': {'symbol': 'A/m2',
#    'name': 'ampere per square meter',
#    'scale': 10.76391041670972,
#    'offset': 0}},
#  'A/m2': {'symbol': 'A/m2',
#   'name': 'ampere per square meter',
#   'measurement': 'current_density',
#   'metric': {'symbol': 'uA/cm2',
#    'name': 'microampere per square centimeter',
#    'scale': 100,
#    'offset': 0},
#   'english': {'symbol': 'uA/cm2',
#    'name': 'microampere per square centimeter',
#    'scale': 100,
#    'offset': 0},
#   'canonical': {'symbol': 'A/m2',
#    'name': 'ampere per square meter',
#    'scale': 1,
#    'offset': 0}},
#  'mA/cm2': {'symbol': 'mA/cm2',
#   'name': 'milliampere per square centimeter',
#   'measurement': 'current_density',
#   'metric': {'symbol': 'uA/cm2',
#    'name': 'microampere per square centimeter',
#    'scale': 1000,
#    'offset': 0},
#   'english': {'symbol': 'uA/cm2',
#    'name': 'microampere per square centimeter',
#    'scale': 1000,
#    'offset': 0},
#   'canonical': {'symbol': 'A/m2',
#    'name': 'ampere per square meter',
#    'scale': 10,
#    'offset': 0}},
#  'mA/ft2': {'symbol': 'mA/ft2',
#   'name': 'milliampere per square foot',
#   'measurement': 'current_density',
#   'metric': {'symbol': 'uA/cm2',
#    'name': 'microampere per square centimeter',
#    'scale': 1.076391041670972,
#    'offset': 0},
#   'english': {'symbol': 'uA/cm2',
#    'name': 'microampere per square centimeter',
#    'scale': 1.076391041670972,
#    'offset': 0},
#   'canonical': {'symbol': 'A/m2',
#    'name': 'ampere per square meter',
#    'scale': 0.01076391041670972,
#    'offset': 0}},
#  'uA/cm2': {'symbol': 'uA/cm2',
#   'name': 'microampere per square centimeter',
#   'measurement': 'current_density',
#   'metric': {'symbol': 'uA/cm2',
#    'name': 'microampere per square centimeter',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': 'uA/cm2',
#    'name': 'microampere per square centimeter',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'A/m2',
#    'name': 'ampere per square meter',
#    'scale': 0.010000000000000002,
#    'offset': 0}},
#  'uA/in2': {'symbol': 'uA/in2',
#   'name': 'microampere per square inch',
#   'measurement': 'current_density',
#   'metric': {'symbol': 'uA/cm2',
#    'name': 'microampere per square centimeter',
#    'scale': 0.15500031000061998,
#    'offset': 0},
#   'english': {'symbol': 'uA/cm2',
#    'name': 'microampere per square centimeter',
#    'scale': 0.15500031000061998,
#    'offset': 0},
#   'canonical': {'symbol': 'A/m2',
#    'name': 'ampere per square meter',
#    'scale': 0.0015500031000061998,
#    'offset': 0}},
#  'g/(cm3.ft)': {'symbol': 'g/(cm3.ft)',
#   'name': 'gram per cubic centimeter per foot',
#   'measurement': 'density_per_length',
#   'metric': {'symbol': 'g/(cm3.m)',
#    'name': 'gram per cubic centimeter per meter',
#    'scale': 3.2808398950131235,
#    'offset': 0},
#   'english': {'symbol': 'g/(cm3.ft)',
#    'name': 'gram per cubic centimeter per foot',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'kg/m4',
#    'name': 'kilogram per cubic meter per meter',
#    'scale': 3280.839895013123,
#    'offset': 0}},
#  'g/(cm3.m)': {'symbol': 'g/(cm3.m)',
#   'name': 'gram per cubic centimeter per meter',
#   'measurement': 'density_per_length',
#   'metric': {'symbol': 'g/(cm3.m)',
#    'name': 'gram per cubic centimeter per meter',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': 'g/(cm3.ft)',
#    'name': 'gram per cubic centimeter per foot',
#    'scale': 0.30479999999999996,
#    'offset': 0},
#   'canonical': {'symbol': 'kg/m4',
#    'name': 'kilogram per cubic meter per meter',
#    'scale': 1000,
#    'offset': 0}},
#  'kg/m4': {'symbol': 'kg/m4',
#   'name': 'kilogram per cubic meter per meter',
#   'measurement': 'density_per_length',
#   'metric': {'symbol': 'g/(cm3.m)',
#    'name': 'gram per cubic centimeter per meter',
#    'scale': 0.001,
#    'offset': 0},
#   'english': {'symbol': 'g/(cm3.ft)',
#    'name': 'gram per cubic centimeter per foot',
#    'scale': 0.00030480000000000004,
#    'offset': 0},
#   'canonical': {'symbol': 'kg/m4',
#    'name': 'kilogram per cubic meter per meter',
#    'scale': 1,
#    'offset': 0}},
#  'A.h': {'symbol': 'A.h',
#   'name': 'Ampere-hour',
#   'measurement': 'electric_charge',
#   'metric': {'symbol': 'C', 'name': 'coulomb', 'scale': 3600, 'offset': 0},
#   'english': {'symbol': 'C', 'name': 'coulomb', 'scale': 3600, 'offset': 0},
#   'canonical': {'symbol': 'C', 'name': 'coulomb', 'scale': 3600, 'offset': 0}},
#  'C': {'symbol': 'C',
#   'name': 'coulomb',
#   'measurement': 'electric_charge',
#   'metric': {'symbol': 'C', 'name': 'coulomb', 'scale': 1, 'offset': 0},
#   'english': {'symbol': 'C', 'name': 'coulomb', 'scale': 1, 'offset': 0},
#   'canonical': {'symbol': 'C', 'name': 'coulomb', 'scale': 1, 'offset': 0}},
#  'eq': {'symbol': 'eq',
#   'name': 'equivalent (electrochemical, as used in cation exchange studies)',
#   'measurement': 'electric_charge',
#   'metric': {'symbol': 'C', 'name': 'coulomb', 'scale': 96487, 'offset': 0},
#   'english': {'symbol': 'C', 'name': 'coulomb', 'scale': 96487, 'offset': 0},
#   'canonical': {'symbol': 'C',
#    'name': 'coulomb',
#    'scale': 96487,
#    'offset': 0}},
#  'fC': {'symbol': 'fC',
#   'name': 'femtocoulomb',
#   'measurement': 'electric_charge',
#   'metric': {'symbol': 'C', 'name': 'coulomb', 'scale': 1e-15, 'offset': 0},
#   'english': {'symbol': 'C', 'name': 'coulomb', 'scale': 1e-15, 'offset': 0},
#   'canonical': {'symbol': 'C',
#    'name': 'coulomb',
#    'scale': 1e-15,
#    'offset': 0}},
#  'kC': {'symbol': 'kC',
#   'name': 'kilocoulomb',
#   'measurement': 'electric_charge',
#   'metric': {'symbol': 'C', 'name': 'coulomb', 'scale': 1000, 'offset': 0},
#   'english': {'symbol': 'C', 'name': 'coulomb', 'scale': 1000, 'offset': 0},
#   'canonical': {'symbol': 'C', 'name': 'coulomb', 'scale': 1000, 'offset': 0}},
#  'mA.h': {'symbol': 'mA.h',
#   'name': 'Milliampere-Hour',
#   'measurement': 'electric_charge',
#   'metric': {'symbol': 'C',
#    'name': 'coulomb',
#    'scale': 3.5999999999999996,
#    'offset': 0},
#   'english': {'symbol': 'C',
#    'name': 'coulomb',
#    'scale': 3.5999999999999996,
#    'offset': 0},
#   'canonical': {'symbol': 'C',
#    'name': 'coulomb',
#    'scale': 3.5999999999999996,
#    'offset': 0}},
#  'mC': {'symbol': 'mC',
#   'name': 'millicoulomb',
#   'measurement': 'electric_charge',
#   'metric': {'symbol': 'C', 'name': 'coulomb', 'scale': 0.001, 'offset': 0},
#   'english': {'symbol': 'C', 'name': 'coulomb', 'scale': 0.001, 'offset': 0},
#   'canonical': {'symbol': 'C',
#    'name': 'coulomb',
#    'scale': 0.001,
#    'offset': 0}},
#  'meq': {'symbol': 'meq',
#   'name': 'milliequivalent (for cation exchange studies)',
#   'measurement': 'electric_charge',
#   'metric': {'symbol': 'C', 'name': 'coulomb', 'scale': 96.487, 'offset': 0},
#   'english': {'symbol': 'C', 'name': 'coulomb', 'scale': 96.487, 'offset': 0},
#   'canonical': {'symbol': 'C',
#    'name': 'coulomb',
#    'scale': 96.487,
#    'offset': 0}},
#  'nC': {'symbol': 'nC',
# ...
#   'name': 'cubic meter per kilogram per million years',
#   'measurement': 'volume_per_mass_per_time',
#   'metric': {'symbol': 'm3/(kg.s)',
#    'name': 'cubic meter per kilogram per second',
#    'scale': 3.16875355494539e-14,
#    'offset': 0},
#   'english': {'symbol': 'm3/(kg.s)',
#    'name': 'cubic meter per kilogram per second',
#    'scale': 3.16875355494539e-14,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/(kg.s)',
#    'name': 'cubic meter per kilogram per second',
#    'scale': 3.16875355494539e-14,
#    'offset': 0}},
#  'm3/(kg.s)': {'symbol': 'm3/(kg.s)',
#   'name': 'cubic meter per kilogram per second',
#   'measurement': 'volume_per_mass_per_time',
#   'metric': {'symbol': 'm3/(kg.s)',
#    'name': 'cubic meter per kilogram per second',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': 'm3/(kg.s)',
#    'name': 'cubic meter per kilogram per second',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/(kg.s)',
#    'name': 'cubic meter per kilogram per second',
#    'scale': 1,
#    'offset': 0}},
#  'bbl/kPa': {'symbol': 'bbl/kPa',
#   'name': 'barrel per kilopascal',
#   'measurement': 'volume_per_pressure',
#   'metric': {'symbol': 'm3/kPa',
#    'name': 'cubic meter per kilopascal',
#    'scale': 0.158987304,
#    'offset': 0},
#   'english': {'symbol': 'bbl/psi',
#    'name': 'barrel per (pound per square inch)',
#    'scale': 6.894757293168359,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/Pa',
#    'name': 'cubic meter per pascal',
#    'scale': 0.000158987304,
#    'offset': 0}},
#  'bbl/psi': {'symbol': 'bbl/psi',
#   'name': 'barrel per (pound per square inch)',
#   'measurement': 'volume_per_pressure',
#   'metric': {'symbol': 'm3/kPa',
#    'name': 'cubic meter per kilopascal',
#    'scale': 0.023059158899985048,
#    'offset': 0},
#   'english': {'symbol': 'bbl/psi',
#    'name': 'barrel per (pound per square inch)',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/Pa',
#    'name': 'cubic meter per pascal',
#    'scale': 2.305915889998505e-05,
#    'offset': 0}},
#  'L/bar': {'symbol': 'L/bar',
#   'name': 'liter per bar',
#   'measurement': 'volume_per_pressure',
#   'metric': {'symbol': 'm3/kPa',
#    'name': 'cubic meter per kilopascal',
#    'scale': 1e-05,
#    'offset': 0},
#   'english': {'symbol': 'bbl/psi',
#    'name': 'barrel per (pound per square inch)',
#    'scale': 0.0004336671620753038,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/Pa',
#    'name': 'cubic meter per pascal',
#    'scale': 1e-08,
#    'offset': 0}},
#  'm3/bar': {'symbol': 'm3/bar',
#   'name': 'cubic meter per bar',
#   'measurement': 'volume_per_pressure',
#   'metric': {'symbol': 'm3/kPa',
#    'name': 'cubic meter per kilopascal',
#    'scale': 0.010000000000000002,
#    'offset': 0},
#   'english': {'symbol': 'bbl/psi',
#    'name': 'barrel per (pound per square inch)',
#    'scale': 0.43366716207530387,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/Pa',
#    'name': 'cubic meter per pascal',
#    'scale': 1e-05,
#    'offset': 0}},
#  'm3/kPa': {'symbol': 'm3/kPa',
#   'name': 'cubic meter per kilopascal',
#   'measurement': 'volume_per_pressure',
#   'metric': {'symbol': 'm3/kPa',
#    'name': 'cubic meter per kilopascal',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': 'bbl/psi',
#    'name': 'barrel per (pound per square inch)',
#    'scale': 43.36671620753038,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/Pa',
#    'name': 'cubic meter per pascal',
#    'scale': 0.001,
#    'offset': 0}},
#  'm3/Pa': {'symbol': 'm3/Pa',
#   'name': 'cubic meter per pascal',
#   'measurement': 'volume_per_pressure',
#   'metric': {'symbol': 'm3/kPa',
#    'name': 'cubic meter per kilopascal',
#    'scale': 1000,
#    'offset': 0},
#   'english': {'symbol': 'bbl/psi',
#    'name': 'barrel per (pound per square inch)',
#    'scale': 43366.71620753038,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/Pa',
#    'name': 'cubic meter per pascal',
#    'scale': 1,
#    'offset': 0}},
#  'm3/psi': {'symbol': 'm3/psi',
#   'name': 'cubic meter per (pound per square inch)',
#   'measurement': 'volume_per_pressure',
#   'metric': {'symbol': 'm3/kPa',
#    'name': 'cubic meter per kilopascal',
#    'scale': 0.1450377377302092,
#    'offset': 0},
#   'english': {'symbol': 'bbl/psi',
#    'name': 'barrel per (pound per square inch)',
#    'scale': 6.2898104115282045,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/Pa',
#    'name': 'cubic meter per pascal',
#    'scale': 0.0001450377377302092,
#    'offset': 0}},
#  '(bbl/d)/(c/s)': {'symbol': '(bbl/d)/(c/s)',
#   'name': '(barrel per day) per (cycle per second)',
#   'measurement': 'volume_per_rotation',
#   'metric': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 2.92865918060809e-07,
#    'offset': 0},
#   'english': {'symbol': 'ft3/rad',
#    'name': 'cubic foot per radian',
#    'scale': 1.0342462290400256e-05,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 2.92865918060809e-07,
#    'offset': 0}},
#  '(bbl/d)/(rev/s)': {'symbol': '(bbl/d)/(rev/s)',
#   'name': 'GeoFrame legacy unit',
#   'measurement': 'volume_per_rotation',
#   'metric': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 2.92865918060809e-07,
#    'offset': 0},
#   'english': {'symbol': 'ft3/rad',
#    'name': 'cubic foot per radian',
#    'scale': 1.0342462290400256e-05,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 2.92865918060809e-07,
#    'offset': 0}},
#  '(m3/d)/(c/s)': {'symbol': '(m3/d)/(c/s)',
#   'name': '(cubic meter per day) per (cycle per second)',
#   'measurement': 'volume_per_rotation',
#   'metric': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 1.8420711006006398e-06,
#    'offset': 0},
#   'english': {'symbol': 'ft3/rad',
#    'name': 'cubic foot per radian',
#    'scale': 6.505212699499727e-05,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 1.8420711006006398e-06,
#    'offset': 0}},
#  '(m3/h)/(c/s)': {'symbol': '(m3/h)/(c/s)',
#   'name': '(cubic meter per hour) per (cycle per second)',
#   'measurement': 'volume_per_rotation',
#   'metric': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 4.4209706414415404e-05,
#    'offset': 0},
#   'english': {'symbol': 'ft3/rad',
#    'name': 'cubic foot per radian',
#    'scale': 0.0015612510478799362,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 4.4209706414415404e-05,
#    'offset': 0}},
#  '(m3/s)/(c/s)': {'symbol': '(m3/s)/(c/s)',
#   'name': '(cubic meter per second) per (cycle per second)',
#   'measurement': 'volume_per_rotation',
#   'metric': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 0.159154943091895,
#    'offset': 0},
#   'english': {'symbol': 'ft3/rad',
#    'name': 'cubic foot per radian',
#    'scale': 5.620503772367756,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 0.159154943091895,
#    'offset': 0}},
#  'bbl.s/(d.c)': {'symbol': 'bbl.s/(d.c)',
#   'name': '(barrel per day) per (cycle per second)',
#   'measurement': 'volume_per_rotation',
#   'metric': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 2.92865918060809e-07,
#    'offset': 0},
#   'english': {'symbol': 'ft3/rad',
#    'name': 'cubic foot per radian',
#    'scale': 1.0342462290400256e-05,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 2.92865918060809e-07,
#    'offset': 0}},
#  'ft3/rad': {'symbol': 'ft3/rad',
#   'name': 'cubic foot per radian',
#   'measurement': 'volume_per_rotation',
#   'metric': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 0.028316846591999997,
#    'offset': 0},
#   'english': {'symbol': 'ft3/rad',
#    'name': 'cubic foot per radian',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 0.028316846591999997,
#    'offset': 0}},
#  'm3.s/(d.c)': {'symbol': 'm3.s/(d.c)',
#   'name': '(cubic meter per day) per (cycle per second)',
#   'measurement': 'volume_per_rotation',
#   'metric': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 1.8420711006006398e-06,
#    'offset': 0},
#   'english': {'symbol': 'ft3/rad',
#    'name': 'cubic foot per radian',
#    'scale': 6.505212699499727e-05,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 1.8420711006006398e-06,
#    'offset': 0}},
#  'm3.s/(h.c)': {'symbol': 'm3.s/(h.c)',
#   'name': '(cubic meter per hour) per (cycle per second)',
#   'measurement': 'volume_per_rotation',
#   'metric': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 4.4209706414415404e-05,
#    'offset': 0},
#   'english': {'symbol': 'ft3/rad',
#    'name': 'cubic foot per radian',
#    'scale': 0.0015612510478799362,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 4.4209706414415404e-05,
#    'offset': 0}},
#  'm3.s/(s.c)': {'symbol': 'm3.s/(s.c)',
#   'name': '(cubic meter per second) per (cycle per second)',
#   'measurement': 'volume_per_rotation',
#   'metric': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 0.159154943091895,
#    'offset': 0},
#   'english': {'symbol': 'ft3/rad',
#    'name': 'cubic foot per radian',
#    'scale': 5.620503772367756,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 0.159154943091895,
#    'offset': 0}},
#  'm3/c': {'symbol': 'm3/c',
#   'name': 'cubic meter per revolution',
#   'measurement': 'volume_per_rotation',
#   'metric': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 0.159154943091895,
#    'offset': 0},
#   'english': {'symbol': 'ft3/rad',
#    'name': 'cubic foot per radian',
#    'scale': 5.620503772367756,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 0.159154943091895,
#    'offset': 0}},
#  'm3/rad': {'symbol': 'm3/rad',
#   'name': 'cubic meter per radian',
#   'measurement': 'volume_per_rotation',
#   'metric': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': 'ft3/rad',
#    'name': 'cubic foot per radian',
#    'scale': 35.31466672148859,
#    'offset': 0},
#   'canonical': {'symbol': 'm3/rad',
#    'name': 'cubic meter per radian',
#    'scale': 1,
#    'offset': 0}},
#  'Btu/(ft3.degF)': {'symbol': 'Btu/(ft3.degF)',
#   'name': 'Btu per cubic foot per degree F',
#   'measurement': 'volumetric_heat_capacity',
#   'metric': {'symbol': 'kg/(K.m.s2)',
#    'name': 'kilogram per Kelvin per meter per square meter',
#    'scale': 67066.1024540963,
#    'offset': 0},
#   'english': {'symbol': 'kg/(K.m.s2)',
#    'name': 'kilogram per Kelvin per meter per square meter',
#    'scale': 67066.1024540963,
#    'offset': 0},
#   'canonical': {'symbol': 'kg/(K.m.s2)',
#    'name': 'kilogram per Kelvin per meter per square meter',
#    'scale': 67066.1024540963,
#    'offset': 0}},
#  'J/(cm3.K)': {'symbol': 'J/(cm3.K)',
#   'name': 'joules per cubic centimetre per Kelvin',
#   'measurement': 'volumetric_heat_capacity',
#   'metric': {'symbol': 'kg/(K.m.s2)',
#    'name': 'kilogram per Kelvin per meter per square meter',
#    'scale': 1000000,
#    'offset': 0},
#   'english': {'symbol': 'kg/(K.m.s2)',
#    'name': 'kilogram per Kelvin per meter per square meter',
#    'scale': 1000000,
#    'offset': 0},
#   'canonical': {'symbol': 'kg/(K.m.s2)',
#    'name': 'kilogram per Kelvin per meter per square meter',
#    'scale': 1000000,
#    'offset': 0}},
#  'J/(m3.K)': {'symbol': 'J/(m3.K)',
#   'name': 'joules per cubic metre per Kelvin',
#   'measurement': 'volumetric_heat_capacity',
#   'metric': {'symbol': 'kg/(K.m.s2)',
#    'name': 'kilogram per Kelvin per meter per square meter',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': 'kg/(K.m.s2)',
#    'name': 'kilogram per Kelvin per meter per square meter',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'kg/(K.m.s2)',
#    'name': 'kilogram per Kelvin per meter per square meter',
#    'scale': 1,
#    'offset': 0}},
#  'kg/(K.m.s2)': {'symbol': 'kg/(K.m.s2)',
#   'name': 'kilogram per Kelvin per meter per square meter',
#   'measurement': 'volumetric_heat_capacity',
#   'metric': {'symbol': 'kg/(K.m.s2)',
#    'name': 'kilogram per Kelvin per meter per square meter',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': 'kg/(K.m.s2)',
#    'name': 'kilogram per Kelvin per meter per square meter',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'kg/(K.m.s2)',
#    'name': 'kilogram per Kelvin per meter per square meter',
#    'scale': 1,
#    'offset': 0}},
#  'kJ/(m3.K)': {'symbol': 'kJ/(m3.K)',
#   'name': 'kilo joules per cubic metre per Kelvin',
#   'measurement': 'volumetric_heat_capacity',
#   'metric': {'symbol': 'kg/(K.m.s2)',
#    'name': 'kilogram per Kelvin per meter per square meter',
#    'scale': 1000,
#    'offset': 0},
#   'english': {'symbol': 'kg/(K.m.s2)',
#    'name': 'kilogram per Kelvin per meter per square meter',
#    'scale': 1000,
#    'offset': 0},
#   'canonical': {'symbol': 'kg/(K.m.s2)',
#    'name': 'kilogram per Kelvin per meter per square meter',
#    'scale': 1000,
#    'offset': 0}},
#  'Btu/(ft3.degF2)': {'symbol': 'Btu/(ft3.degF2)',
#   'name': 'Btu per cubic foot per degree F squared',
#   'measurement': 'volumetric_heat_capacity_per_temperature',
#   'metric': {'symbol': 'kg/(K2.m.s2)',
#    'name': 'kilogram per Kelvin squared per meter per square meter',
#    'scale': 120718.98441737298,
#    'offset': 0},
#   'english': {'symbol': 'kg/(K2.m.s2)',
#    'name': 'kilogram per Kelvin squared per meter per square meter',
#    'scale': 120718.98441737298,
#    'offset': 0},
#   'canonical': {'symbol': 'kg/(K2.m.s2)',
#    'name': 'kilogram per Kelvin squared per meter per square meter',
#    'scale': 120718.98441737298,
#    'offset': 0}},
#  'J/(cm3.K2)': {'symbol': 'J/(cm3.K2)',
#   'name': 'joules per cubic centimetre per Kelvin squared',
#   'measurement': 'volumetric_heat_capacity_per_temperature',
#   'metric': {'symbol': 'kg/(K2.m.s2)',
#    'name': 'kilogram per Kelvin squared per meter per square meter',
#    'scale': 1000000,
#    'offset': 0},
#   'english': {'symbol': 'kg/(K2.m.s2)',
#    'name': 'kilogram per Kelvin squared per meter per square meter',
#    'scale': 1000000,
#    'offset': 0},
#   'canonical': {'symbol': 'kg/(K2.m.s2)',
#    'name': 'kilogram per Kelvin squared per meter per square meter',
#    'scale': 1000000,
#    'offset': 0}},
#  'J/(m3.K2)': {'symbol': 'J/(m3.K2)',
#   'name': 'joules per cubic metre per Kelvin squared',
#   'measurement': 'volumetric_heat_capacity_per_temperature',
#   'metric': {'symbol': 'kg/(K2.m.s2)',
#    'name': 'kilogram per Kelvin squared per meter per square meter',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': 'kg/(K2.m.s2)',
#    'name': 'kilogram per Kelvin squared per meter per square meter',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'kg/(K2.m.s2)',
#    'name': 'kilogram per Kelvin squared per meter per square meter',
#    'scale': 1,
#    'offset': 0}},
#  'kg/(K2.m.s2)': {'symbol': 'kg/(K2.m.s2)',
#   'name': 'kilogram per Kelvin squared per meter per square meter',
#   'measurement': 'volumetric_heat_capacity_per_temperature',
#   'metric': {'symbol': 'kg/(K2.m.s2)',
#    'name': 'kilogram per Kelvin squared per meter per square meter',
#    'scale': 1,
#    'offset': 0},
#   'english': {'symbol': 'kg/(K2.m.s2)',
#    'name': 'kilogram per Kelvin squared per meter per square meter',
#    'scale': 1,
#    'offset': 0},
#   'canonical': {'symbol': 'kg/(K2.m.s2)',
#    'name': 'kilogram per Kelvin squared per meter per square meter',
#    'scale': 1,
#    'offset': 0}},
#  'kJ/(m3.K2)': {'symbol': 'kJ/(m3.K2)',
#   'name': 'kilo joules per cubic metre per Kelvin squared',
#   'measurement': 'volumetric_heat_capacity_per_temperature',
#   'metric': {'symbol': 'kg/(K2.m.s2)',
#    'name': 'kilogram per Kelvin squared per meter per square meter',
#    'scale': 1000,
#    'offset': 0},
#   'english': {'symbol': 'kg/(K2.m.s2)',
#    'name': 'kilogram per Kelvin squared per meter per square meter',
#    'scale': 1000,
#    'offset': 0},
#   'canonical': {'symbol': 'kg/(K2.m.s2)',
#    'name': 'kilogram per Kelvin squared per meter per square meter',
#    'scale': 1000,
#    'offset': 0}}}

# %%
units_converter.convert_to_canonical??

# %% [markdown]
# # Examples

# %% [markdown]
# ## Get information about a given unit

# %%
units_converter.units_table['ft/s2']
# Out:
# {'symbol': 'ft/s2',
#  'name': 'foot per square second',
#  'measurement': 'acceleration',
#  'metric': {'symbol': 'm/s2',
#   'name': 'meter per square second',
#   'scale': 0.30479999999999996,
#   'offset': 0},
#  'english': {'symbol': 'ft/s2',
#   'name': 'foot per square second',
#   'scale': 1,
#   'offset': 0},
#  'canonical': {'symbol': 'm/s2',
#   'name': 'meter per square second',
#   'scale': 0.30479999999999996,
#   'offset': 0}}

# %%
print( units_converter.units_table['kPa'] )
# Out:
# {'symbol': 'kPa', 'name': 'kilopascal', 'measurement': 'pressure', 'metric': {'symbol': 'kPa', 'name': 'kilopascal', 'scale': 1, 'offset': 0}, 'english': {'symbol': 'psi', 'name': 'pound per square inch', 'scale': 0.14503773773020923, 'offset': 0}, 'canonical': {'symbol': 'Pa', 'name': 'pascal', 'scale': 1000, 'offset': 0}}

# %%
print( units_converter.units_table['us/ft'] )
# Out:
# {'symbol': 'us/ft', 'name': 'microsecond per foot', 'measurement': 'time_per_length', 'metric': {'symbol': 's/m', 'name': 'second per meter', 'scale': 3.2808398950131235e-06, 'offset': 0}, 'english': {'symbol': 's/ft', 'name': 'second per foot', 'scale': 9.999999999999997e-07, 'offset': 0}, 'canonical': {'symbol': 's/m', 'name': 'second per meter', 'scale': 3.2808398950131235e-06, 'offset': 0}}

# %%
print('1D = ', units_converter.convert_to_canonical( 1 , 'D') )
print( units_converter.units_table['D'])
# Out:
# 1D =  (9.869232999999999e-13, 'm2')
# {'symbol': 'D', 'name': 'darcy', 'measurement': 'area', 'metric': {'symbol': 'm2', 'name': 'square meter', 'scale': 9.869232999999999e-13, 'offset': 0}, 'english': {'symbol': 'ft2', 'name': 'square foot', 'scale': 1.0623153989363533e-11, 'offset': 0}, 'canonical': {'symbol': 'm2', 'name': 'square meter', 'scale': 9.869232999999999e-13, 'offset': 0}}

# %% [markdown]
# ## Convert numpy arrays, lists or scalar values

# %%
print('\nexample 1: scalar values unit-symbol to unit-symbol') 
symbol1 = 'm'
symbol2 = 'mm'
milimeters= units_converter.convert( 1,symbol1, symbol2)
print( '1 m equals',milimeters, ' mm' )
# Out:
# example 1: scalar values unit-symbol to unit-symbol
# 1 m equals 1000.0  mm

# %%
#convert a list of values, including np.nan or a numpy array 
print('\nexample 2.1: list of values') 
values = [1,10,100, np.nan] 
units  = 'cm'

converted, to_symbol = units_converter.convert_to_canonical( [1,10,100, np.nan] , units)
print ( '{} {} = {}{}'.format(values, units, converted, to_symbol))
print('return type = ', type(converted)  ) 

 
print('\nexample 2.2: numpy array') 
nparray = np.array( values )
converted, to_symbol = units_converter.convert_to_canonical( nparray, units)
print ( '{} {} = {}{}'.format(values, units, converted, to_symbol))
print('return type = ', type(converted)  )
# Out:
# example 2.1: list of values
# [1, 10, 100, nan] cm = [0.01 0.1  1.    nan]m
# return type =  <class 'numpy.ndarray'>
#
# example 2.2: numpy array
# [1, 10, 100, nan] cm = [0.01 0.1  1.    nan]m
# return type =  <class 'numpy.ndarray'>

# %%
densiy_log = np.array( [2.1,2.2,2.1,1.9,2.36] ) 

#to metric 
metric_values, metric_symbol = units_converter.convert_to_system('metric', densiy_log, 'g/cm3')
print(metric_values, metric_symbol) 

print()

#to english 
english_values, english_symbol = units_converter.convert_to_system('english', densiy_log, 'g/cm3')
print(english_values, english_symbol)
# Out:
# [2100. 2200. 2100. 1900. 2360.] kg/m3
#
# [736.06471467 771.11541537 736.06471467 665.96331327 827.19653648] lbm/bbl

# %%
    
print('\nexample 4') 
symbol1 = 'in2'
converted,canonical_symbol =  units_converter.convert_to_canonical( 1, symbol1)
print('1 inch squared is ', converted, canonical_symbol)

print('\nexample 4') 
back_to_in2 = units_converter.convert(converted,canonical_symbol, symbol1)
print(converted,canonical_symbol,' converted to ', symbol1, ' is ',back_to_in2)
# Out:
# example 4
# 1 inch squared is  0.0006451600000000001 m2
#
# example 4
# 0.0006451600000000001 m2  converted to  in2  is  1.0

# %% [markdown]
# ## Temperatures

# %%
print('\nexample 5: convert temperatures')
celcius = 25.0 
farenheit = units_converter.convert(celcius, 'degC','degF')
print('{} degrees celcius equals {} degrees Farenheit'.format(celcius,farenheit))

celcius = units_converter.convert(77, 'degF', 'degC')
print('{} degrees Farenheit equals {} degrees Celcius'.format(77,celcius))

kelvin = units_converter.convert_to_canonical(25, 'degC')
print('{} degrees Celcius equals {}, where K stands for Kelvin degrees'.format(25,kelvin))
# Out:
# example 5: convert temperatures
# 25.0 degrees celcius equals 76.99999999999989 degrees Farenheit
# 77 degrees Farenheit equals 25.000000000000057 degrees Celcius
# 25 degrees Celcius equals (298.15, 'K'), where K stands for Kelvin degrees

# %% [markdown]
# ## Pressure gradients

# %%
print('\nexample 6: convert pressure gradients')

converted = units_converter.convert_to_canonical(0.44, 'psi/ft')
print('0.44 psi/ft equals', converted[0], converted[1])
print('0.44 psi/ft -> kPa/m: equals', units_converter.convert(0.44, 'psi/ft', 'kPa/m'))
# Out:
# example 6: convert pressure gradients
# 0.44 psi/ft equals 9953.061709298157 Pa/m
# 0.44 psi/ft -> kPa/m: equals 9.953061709298158

# %% [markdown]
# ## Other units

# %%
print('\nexample 7: weird units')
weird = 1.0e-14
init_symbol ='bar/(rm3/d)2'
units_converter.print_conversions( weird, init_symbol)
# Out:
# example 7: weird units
# bar per reservoir cubic meter per day squared ( pressure_per_flowrate_squared )
# 1e-14 bar/(rm3/d)2 converted to kg/m7 in the canonical system equals 7.46496 kilogram per meter to the seventh
# 1e-14 bar/(rm3/d)2 converted to kg/m7 in the metric system equals 7.46496 kilogram per meter to the seventh
# 1e-14 bar/(rm3/d)2 converted to kg/m7 in the english system equals 7.46496 kilogram per meter to the seventh

# %% [markdown]
# ## Get the units for a given known measurement

# %%
units_converter.symbols_for_measurement['velocity']
# Out:
# {'metric': 'm/s', 'canonical': 'm/s', 'english': 'ft/s'}

# %%
units_converter.symbols_for_measurement['velocity']['english']
# Out:
# 'ft/s'

# %%
units_converter.symbols_for_measurement['area_squared']
# Out:
# {'metric': 'm4', 'canonical': 'm4', 'english': 'm4'}

# %%
## All knwon unit symbols for a given measurement

# %%
energy_units= [ key for key,value in units_converter.units_table.items() if 'energy' in value['measurement']]

#these may include field units. 
print( energy_units[0:20], '\n' )

print( units_converter.symbols_for_measurement['energy'])

name = units_converter.units_table['J']['name']
print( 'The name of J is ', name  )

name = units_converter.units_table['ft.lbf']['name']
print( 'The name of ft.lbf is ', name  )
# Out:
# ['aJ', 'Btu', 'cal', 'EJ', 'eV', 'ft.lbf', 'GeV', 'GJ', 'in.lbf', 'J', 'kcal', 'keV', 'kgf.m', 'kJ', 'km.daN', 'kN.m', 'kW.h', 'MeV', 'mJ', 'MJ']
#
# {'metric': 'keV', 'canonical': 'J', 'english': 'keV'}
# The name of J is  joule
# The name of ft.lbf is  foot-pound force

# %% [markdown]
# ## Symbols of known measurements for the three main systems

# %%
units_converter.symbols_for_system['metric'][10:20]
# Out:
# ['kPa/m',
#  's',
#  's/kg',
#  'mA',
#  'J/mol',
#  '1000 m4/d',
#  'm2/(K4.s2)',
#  'm/kPa',
#  'kg.m',
#  'mol/s']

# %%
units_converter.symbols_for_system['english'][10:20]
# Out:
# ['lx',
#  'ft',
#  's',
#  'lbm/ft2',
#  'degF',
#  's/kg',
#  'mA',
#  'lbm/bbl',
#  'J/mol',
#  'lbm/(ft.s)']

# %% [markdown]
# ## Dimensionless symbol

# %%
units_converter.dimensionless_symbols[0:10]
# Out:
# ['_',
#  'b/e',
#  'bbl/(acre.ft)',
#  'bbl/bbl',
#  'bbl/ft3',
#  'bbl/SCF',
#  'bbl/STB',
#  'cm3/cm3',
#  'ft/m',
#  'ft3/bbl']

# %% [markdown]
# # Example:
# #### Read slowness in a log with arbitrary units and compute the velocity in the canonical system

# %%
#Example: 
## Read slowness in arbitrary units and compute the velocity in the canonical system
  
slowness = np.array( [130.,220.0 ] ) #array read from file or delfi
symbol   =  'us/ft'                  #unit symbol read 

#convert to canonical 
slowness_canonical, _ = units_converter.convert_to_canonical( slowness, symbol)

#get the velocity 
velocity = 1.0/slowness_canonical

#get the units of the velocity in the canonical 
velocity_units = units_converter.symbols_for_measurement['velocity']['canonical']

print('The velocity is')
print( velocity, velocity_units )
# Out:
# The velocity is
# [2344.61538462 1385.45454545] m/s

# %%
units_converter.symbols_for_measurement['velocity']
# Out:
# {'metric': 'm/s', 'canonical': 'm/s', 'english': 'ft/s'}

# %%
units_converter.units_table['us/ft']
# Out:
# {'symbol': 'us/ft',
#  'name': 'microsecond per foot',
#  'measurement': 'time_per_length',
#  'metric': {'symbol': 's/m',
#   'name': 'second per meter',
#   'scale': 3.2808398950131235e-06,
#   'offset': 0},
#  'english': {'symbol': 's/ft',
#   'name': 'second per foot',
#   'scale': 9.999999999999997e-07,
#   'offset': 0},
#  'canonical': {'symbol': 's/m',
#   'name': 'second per meter',
#   'scale': 3.2808398950131235e-06,
#   'offset': 0}}

# %%
units_converter.print_conversions(1,'us/ft')
# Out:
# microsecond per foot ( time_per_length )
# 1 us/ft converted to s/m in the canonical system equals 3.2808398950131235e-06 second per meter
# 1 us/ft converted to s/m in the metric system equals 3.2808398950131235e-06 second per meter
# 1 us/ft converted to s/ft in the english system equals 9.999999999999997e-07 second per foot
